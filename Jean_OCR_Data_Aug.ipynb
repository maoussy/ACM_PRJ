# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# %%
import os
import random
import numpy as np
import time
from PIL import ImageFile, Image
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import os
import keras_ocr
import torchvision.models as models

# %%
SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
train_transforms = transforms.Compose([transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
                                                 transforms.RandomRotation(degrees=5),
                                                 transforms.ColorJitter(),
                                                 #transforms.RandomHorizontalFlip(),
                                                 transforms.CenterCrop(size=224),	# Image net standards
                                                 #transforms.Resize((112,112)),
                                                 #transforms.Resize((224,224)),
                                                 transforms.ToTensor(),
                                                 transforms.Normalize([0.5, 0.5, 0.5],
                                                 [0.5, 0.5, 0.5])
                                             ])

test_transforms = transforms.Compose([
                                        #transforms.CenterCrop((224, 224)),
                                        transforms.Resize((224,224)),
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5, 0.5, 0.5),(0.5, 0.5, 0.5))
                                    ])

# %%
train_data = datasets.ImageFolder(r"C:\Users\Jean-Michel\Downloads\my_data_aug\my_data_aug\train", train_transforms)
test_data = datasets.ImageFolder(r"C:\Users\Jean-Michel\Downloads\my_data_aug\my_data_aug\test", test_transforms)

# %%
n_train_examples = int(len(train_data)*0.8)
n_valid_examples = n_test_examples = len(train_data) - n_train_examples

train_data, valid_data = torch.utils.data.random_split(train_data, [n_train_examples, n_valid_examples])

# %%
print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 4844
# Number of validation examples: 1212
# Number of testing examples: 1457

# %%
BATCH_SIZE = 32
train_iterator = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=BATCH_SIZE)
valid_iterator = torch.utils.data.DataLoader(valid_data, batch_size=BATCH_SIZE)
test_iterator = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE)

device = torch.device('cuda')

# %%
def train(model, device, iterator, optimizer, criterion):  
    epoch_loss = 0
    epoch_acc = 0
    model.train()
    for (x, y) in iterator:
        data = ocr(x)
        data = data.to(device)
        y = y.to(device)
        optimizer.zero_grad()  
        fx = model(data).to(device)
        loss = criterion(fx, y)
        acc = calculate_accuracy(fx, y)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

def evaluate(model, device, iterator, criterion):
    epoch_loss = 0
    epoch_acc = 0
    model.eval()
    
    with torch.no_grad():
        for (x, y) in iterator:
            data = ocr(x)
            data = data.to(device)
            y = y.to(device)
            fx = model(data).to(device)
            loss = criterion(fx, y)
            acc = calculate_accuracy(fx, y)
            epoch_loss += loss.item()
            epoch_acc += acc.item()
    
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = correct.float()/preds.shape[0]
    return acc

# %%
def ocr(x):
    images = []
    n_images = x.shape[0] 
    for i in range(n_images):
        im = x[0].cpu().permute(1,2,0)
        im = im*0.5+0.5
        im = im.numpy()
        im = im*255
        images.append(im)
    prediction_groups = pipeline.recognize(images)
    word_list = ['signal', 'stop', 'ahead', 'speed', 'limit', '15', '30', '35', '45', '55', '65', 'right', 'left', 'lane', 'ends', 'do', 'not', 'enter', 'yield']
    data = torch.zeros(n_images,len(word_list))
    for i in range(n_images):
        n_words = len(prediction_groups[i])
        for j in range(n_words):
            word = prediction_groups[i][j][0]
            for k in range(len(word_list)):
                if(word == word_list[k]):
                    data[i,k] = 1
    return data

# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
D_in, H, D_out = 19, 100, 18

# Use the nn package to define our model as a sequence of layers. nn.Sequential
# is a Module which contains other Modules, and applies them in sequence to
# produce its output. Each Linear Module computes output from input using a
# linear function, and holds internal Tensors for its weight and bias.
model = torch.nn.Sequential(
    torch.nn.Linear(D_in, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, D_out),
)

# %%
model = model.to(device)

for param in model.parameters():
	param.requires_grad = True

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# The nn package also contains definitions of popular loss functions; in this
# case we will use Mean Squared Error (MSE) as our loss function.

t_train_acc = []
t_val_acc = []
t_train_loss = []
t_val_loss = []

# %%
EPOCHS = 50
SAVE_DIR = 'models'
MODEL_SAVE_PATH = os.path.join(SAVE_DIR, 'ocr.pt')
best_valid_loss = float('inf')
pipeline = keras_ocr.pipeline.Pipeline()

for epoch in range(EPOCHS):

    start = time.time()
    
    train_loss, train_acc = train(model, device, train_iterator, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, device, valid_iterator, criterion)


    t_train_loss.append(train_loss)
    t_train_acc.append(train_acc)

    t_val_acc.append(valid_acc)
    t_val_loss.append(valid_loss)
   

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), MODEL_SAVE_PATH)

    T = time.time() - start

    print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:05.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:05.2f}% | T: {T:0.2f}s|')
# Out:
# Looking for C:\Users\Jean-Michel\.keras-ocr\craft_mlt_25k.h5
# Downloading C:\Users\Jean-Michel\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\Jean-Michel\.keras-ocr\crnn_kurapan.h5
# Downloading C:\Users\Jean-Michel\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 8s 8s/step
# 2/2 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 530ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 524ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 520ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 532ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 526ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 554ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 540ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 542ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 538ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 542ms/step
# 1/1 [==============================] - 7s 7s/step
# 6/6 [==============================] - 3s 525ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 530ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 530ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 542ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 531ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 532ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 545ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 556ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 542ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 544ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 559ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 567ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 561ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 545ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 10/10 [==============================] - 6s 559ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 551ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 553ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 552ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 574ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 562ms/step
# 1/1 [==============================] - 9s 9s/step
# 2/2 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 560ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 576ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 573ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 716ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 573ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 588ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 586ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 582ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 582ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 575ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 4/4 [==============================] - 3s 679ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 732ms/step
# 1/1 [==============================] - 9s 9s/step
# 4/4 [==============================] - 3s 736ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 726ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 725ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 4/4 [==============================] - 2s 587ms/step
# 1/1 [==============================] - 9s 9s/step
# 6/6 [==============================] - 4s 722ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 587ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 10s 10s/step
# 3/3 [==============================] - 2s 750ms/step
# 1/1 [==============================] - 10s 10s/step
# 5/5 [==============================] - 4s 751ms/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 1s 794ms/step
# 1/1 [==============================] - 10s 10s/step
# 3/3 [==============================] - 2s 751ms/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 10s 10s/step
# 3/3 [==============================] - 2s 742ms/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 536ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 533ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 536ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 527ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 528ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 544ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 528ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 535ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 4/4 [==============================] - 2s 447ms/step
# | Epoch: 01 | Train Loss: 2.778 | Train Acc: 10.75% | Val. Loss: 2.709 | Val. Acc: 13.30% | T: 1777.40s|
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 536ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 542ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 532ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 538ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 535ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 564ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 553ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 540ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 531ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 532ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 7s 7s/step
# 6/6 [==============================] - 3s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 553ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 544ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 536ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 536ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 535ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 530ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 536ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 7s 7s/step
# 9/9 [==============================] - 5s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 533ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 542ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 538ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 541ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 529ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 544ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 534ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 569ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 7s 7s/step
# 8/8 [==============================] - 4s 545ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 529ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 566ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 577ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 531ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 553ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 568ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 539ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 537ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 531ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 6/6 [==============================] - 3s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 570ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 549ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 564ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 620ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 578ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 604ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 567ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 2/2 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 8s 8s/step
# 6/6 [==============================] - 3s 569ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 572ms/step
# 1/1 [==============================] - 8s 8s/step
# 2/2 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 8s 8s/step
# 4/4 [==============================] - 2s 559ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 2/2 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 9s 9s/step
# 4/4 [==============================] - 3s 667ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 3s 3s/step
# 2/2 [==============================] - 1s 113ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 616ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 9s 9s/step
# 3/3 [==============================] - 2s 679ms/step
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 558ms/step
# 1/1 [==============================] - 8s 8s/step
# 2/2 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 579ms/step
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 2s 559ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 561ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 561ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 564ms/step
# 1/1 [==============================] - 7s 7s/step
# 6/6 [==============================] - 3s 565ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 559ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 571ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 561ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 570ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 561ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 4/4 [==============================] - 2s 459ms/step
# | Epoch: 02 | Train Loss: 2.699 | Train Acc: 12.16% | Val. Loss: 2.685 | Val. Acc: 12.97% | T: 1744.61s|
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 552ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 555ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 531ms/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 560ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 548ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 556ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 7s 7s/step
# 7/7 [==============================] - 4s 549ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 4/4 [==============================] - 2s 556ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 556ms/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 546ms/step
# 1/1 [==============================] - 7s 7s/step
# 5/5 [==============================] - 3s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 6/6 [==============================] - 3s 557ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 555ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 575ms/step
# 1/1 [==============================] - 7s 7s/step
# 2/2 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 550ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 3/3 [==============================] - 2s 547ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/3 [=========>....................] - ETA: 1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 11
#       7 for epoch in range(EPOCHS):
#       9     start = time.time()
# ---> 11     train_loss, train_acc = train(model, device, train_iterator, optimizer, criterion)
#      12     valid_loss, valid_acc = evaluate(model, device, valid_iterator, criterion)
#      15     t_train_loss.append(train_loss)
#
# Cell In[11], line 6, in train(model, device, iterator, optimizer, criterion)
#       4 model.train()
#       5 for (x, y) in iterator:
# ----> 6     data = ocr(x)
#       7     data = data.to(device)
#       8     y = y.to(device)
#
# Cell In[18], line 10, in ocr(x)
#       8     im = im*255
#       9     images.append(im)
# ---> 10 prediction_groups = pipeline.recognize(images)
#      11 word_list = ['signal', 'stop', 'ahead', 'speed', 'limit', '15', '30', '35', '45', '55', '65', 'right', 'left', 'lane', 'ends', 'do', 'not', 'enter', 'yield']
#      12 data = torch.zeros(n_images,len(word_list))
#
# File ~\Jean_Python_files\lib\site-packages\keras_ocr\pipeline.py:63, in Pipeline.recognize(self, images, detection_kwargs, recognition_kwargs)
#      61     recognition_kwargs = {}
#      62 box_groups = self.detector.detect(images=images, **detection_kwargs)
# ---> 63 prediction_groups = self.recognizer.recognize_from_boxes(
#      64     images=images, box_groups=box_groups, **recognition_kwargs
#      65 )
#      66 box_groups = [
#      67     tools.adjust_boxes(boxes=boxes, boxes_format="boxes", scale=1 / scale)
#      68     if scale != 1
#      69     else boxes
#      70     for boxes, scale in zip(box_groups, scales)
#      71 ]
#      72 return [
#      73     list(zip(predictions, boxes))
#      74     for predictions, boxes in zip(prediction_groups, box_groups)
#      75 ]
#
# File ~\Jean_Python_files\lib\site-packages\keras_ocr\recognition.py:540, in Recognizer.recognize_from_boxes(self, images, box_groups, **kwargs)
#     530 if len(X.shape) == 3:
#     531     X = X[..., np.newaxis]
#     532 predictions = [
#     533     "".join(
#     534         [
#     535             self.alphabet[idx]
#     536             for idx in row
#     537             if idx not in [self.blank_label_idx, -1]
#     538         ]
#     539     )
# --> 540     for row in self.prediction_model.predict(X, **kwargs)
#     541 ]
#     542 return [predictions[start:end] for start, end in start_end]
#
# File ~\Jean_Python_files\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Jean_Python_files\lib\site-packages\keras\engine\training.py:2382, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2380 for step in data_handler.steps():
#    2381     callbacks.on_predict_batch_begin(step)
# -> 2382     tmp_batch_outputs = self.predict_function(iterator)
#    2383     if data_handler.should_sync:
#    2384         context.async_wait()
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\Jean_Python_files\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
